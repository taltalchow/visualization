# %% [markdown]
# Link to data set: https://open.toronto.ca/dataset/red-light-cameras/
#
# # I downloaded the CSV data set

# %%
#Link to Tableau graph
# https://public.tableau.com/authoring/redlightcamera/1#1

# %% [markdown]
# # Visualization 2: Red Light Camera Installations by Year (Tableau)
#
#  > What software did you use to create your data visualization?
#  I used Tableau Publics to create this bar chat
#
# > Who is your intended audience?
# This visualization is intended for Toronto residents, urban planners, city officials and anyone who want to understand the geographic distribution of active red light cameras in Toronto.
#
# > What information or message are you trying to convey with your visualization?
# The goal of this visualization is to show the trend of red light camera installations in Toronto. By visualizing the number of installations per year, we can identify patterns in policy implementation and investment in traffic safety infrastructure.
#
# > What aspects of design did you consider when making your visualization? How did you apply them? With what elements of your plots?
# I used a bar chart to easily compare how many cameras were installed each year.
# X-axis shows the year
# Y-axis shows the number of cameras
# I renamed the Y-axis to make it clear: “Number of Red Light Camera Installations in Year”
# The bars are in clear color so it’s easy to read and understand at a glance.
#
# > How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
# The chart can be recreated by: Downloading the same dataset from Toronto Open Data
# Using Tableau (or Excel) to group the activation dates by year
# Counting _id to get the number of installations
# I also saved the chart as a PNG, so it’s easy to share.
#
# > How did you ensure that your data visualization is accessible?
# I added clear titles and labels and used high-contrast colors. The height of each bar shows the data clearly, even if someone can’t see color well.
#
# > Who are the individuals and communities who might be impacted by your visualization?
# People living in areas with more cameras, city planners, journalists, and community groups might use this to understand where cameras are placed and how it's changed over time.
#
# > How did you choose which features of your chosen dataset to include or exclude from your visualization?
# I only used: The activation year, The count of cameras
# Other columns (like location or ward) were not used to keep the chart simple and focused.
#
# > What ‘underwater labour’ contributed to your final data visualization product?
# I cleaned the activation date and converted it to year. Learned how to use Tableau’s drag-and-drop tools and exported the chart as a PNG for my assignment.
